# %% [markdown]
# # Introduction

# %% [markdown]
# ## Libraries and their Purposes
#
# 1. **pandas (pd):**
#    - Provides data structures like DataFrames for efficient data manipulation and analysis.
#    - Enables reading and writing data from various file formats (e.g., CSV, Excel).
#    - Offers tools for data cleaning, transformation, and aggregation.
#
# 2. **NumPy (np):**
#    - Supports numerical operations, especially with arrays and matrices.
#    - Offers functionalities for mathematical computations, linear algebra, and random number generation.
#    - Forms the foundation for many scientific computing libraries in Python.
#
# 3. **Matplotlib.pyplot (plt):**
#    - Used for creating static, interactive, and animated visualizations in Python.
#    - Provides a wide range of plotting functions for generating charts, graphs, and other visual representations of data.
#    - Offers customization options for plot aesthetics and formatting.
#
# 4. **Seaborn (sns):**
#    - Built on top of Matplotlib, Seaborn provides a high-level interface for creating informative and attractive statistical graphics.
#    - Simplifies the creation of complex visualizations like heatmaps, violin plots, and pair plots.
#    - Offers themes and color palettes for visually appealing data representations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###### This code snippet is crucial for starting any analysis with the Boston Housing dataset. It imports the data from the CSV file into a structured format (DataFrame) that can be easily manipulated and analyzed using pandas functionalities.

# %%
df = pd.read_csv('/content/boston.csv')

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %% [markdown]
# #1.
# Correlation between Number of Rooms and Median Value

# %%
correlation = df['RM'].corr(df['MEDV'])

# %%
correlation
# Out:
# 0.6953599470715393

# %% [markdown]
# # 2. Variable with Highest Correlation with Median Value

# %%
correlations = df.corr()['MEDV'].abs().sort_values(ascending=False)
highest_correlation_variable = correlations.index[1]  # Exclude 'MEDV' itself

# %%
correlations
# Out:
# MEDV       1.000000
# LSTAT      0.737663
# RM         0.695360
# PTRATIO    0.507787
# INDUS      0.483725
# TAX        0.468536
# NOX        0.427321
# CRIM       0.388305
# RAD        0.381626
# AGE        0.376955
# ZN         0.360445
# B          0.333461
# DIS        0.249929
# CHAS       0.175260
# Name: MEDV, dtype: float64

# %% [markdown]
# # 3.Distribution of Pupil-Teacher Ratio by Town

# %%
plt.hist(df['PTRATIO'])
plt.xlabel('Pupil-Teacher Ratio')
plt.ylabel('Frequency')
plt.title('Distribution of Pupil-Teacher Ratio by Town')
plt.show()

# %% [markdown]
# # 4. Average Age of Homes

# %%
average_age = df['AGE'].mean()

# %%
average_age
# Out:
# 68.57490118577076

# %% [markdown]
# # 5. Town with Highest Median Value

# %%
index_of_max_medv = df['MEDV'].idxmax()

# %%
index_of_max_medv
# Out:
# 161

# %%
row_with_highest_medv = df.loc[index_of_max_medv]

# %%
row_with_highest_medv
# Out:
# CRIM         1.46336
# ZN           0.00000
# INDUS       19.58000
# CHAS         0.00000
# NOX          0.60500
# RM           7.48900
# AGE         90.80000
# DIS          1.97090
# RAD          5.00000
# TAX        403.00000
# PTRATIO     14.70000
# B          374.43000
# LSTAT        1.73000
# MEDV        50.00000
# Name: 161, dtype: float64
